# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Column Manipulation

# %%
csvpath = Path("../Resources/customers.csv")

# %%
customer_dataframe = pd.read_csv(csvpath)
customer_dataframe.head()
# Out:
#           FullName                     Email                  Address    Zip  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension  31353
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza   1922
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway  41535
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace  16098
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade  99895
#
#             CreditCard  Balance
# 0  2524 2317 2139 4751    21511
# 1  4756 0997 9568 1329    13850
# 2    3717 863466 48574    21254
# 3  5413 1700 6989 2835     5221
# 4  5173 4883 9215 4743     8300

# %% [markdown]
# ### Replace Columns

# %%
# Display column names
customer_dataframe.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'Balance'], dtype='object')

# %%
# Rewrite the column names
customer_dataframe.columns = ['Full Name', 'Email', 'Address', 'Zip Code', 'Credit Card Number', 'Account Balance']

# %% [markdown]
# ### Rename Columns

# %%
customer_dataframe.rename(columns={
    'Full Name': 'full_name',
    'Credit Card Number': 'credit_card_number'
}
)
# Out:
#             Full Name                     Email                    Address  \
# 0     Altha Frederick  unhideable1966@gmail.com    67 John Maher Extension
# 1     Nickolas Harvey   allgood1803@outlook.com          1200 Madera Plaza
# 2     Jesusita Kinney    satsumas1954@yahoo.com           943 Gibb Highway
# 3         Mose Gordon    antifowl1875@gmail.com            1073 Fell Trace
# 4     Cesar Valentine  acetaminol1979@yahoo.com     805 Marshall Promenade
# ..                ...                       ...                        ...
# 95     Crystle Larson     plantula1818@live.com  1317 Cesar Chavez On Brae
# 96    Jetta Davenport  doolittle1818@yandex.com       618 Williams Terrace
# 97    Dallas Johnston        mosso1961@live.com             324 Tenny Line
# 98  Roberto Daugherty    ovenful1914@yandex.com         1058 Marengo Manor
# 99       Abel Walters      esson1909@yandex.com           89 Rivera Bypass
#
#     Zip Code   Credit Card Number  Account Balance
# 0      31353  2524 2317 2139 4751            21511
# 1       1922  4756 0997 9568 1329            13850
# 2      41535    3717 863466 48574            21254
# 3      16098  5413 1700 6989 2835             5221
# 4      99895  5173 4883 9215 4743             8300
# ..       ...                  ...              ...
# 95     74413    3474 949615 85541             5091
# 96     73152  4711 5533 4972 2249            16509
# 97     88215    3794 280688 77410            24196
# 98     33903  4972 5355 6633 9108            18828
# 99     39186    3727 728484 48704             3400
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Reorder Columns

# %%
customer_dataframe.columns
# Out:
# Index(['Full Name', 'Email', 'Address', 'Zip Code', 'Credit Card Number',
#        'Account Balance'],
#       dtype='object')

# %%
customer_dataframe = customer_dataframe[['Email', 'Full Name', 'Zip Code', 'Address', 'Credit Card Number',
       'Account Balance']]
# Out:
#                        Email          Full Name  Zip Code  \
# 0   unhideable1966@gmail.com    Altha Frederick     31353
# 1    allgood1803@outlook.com    Nickolas Harvey      1922
# 2     satsumas1954@yahoo.com    Jesusita Kinney     41535
# 3     antifowl1875@gmail.com        Mose Gordon     16098
# 4   acetaminol1979@yahoo.com    Cesar Valentine     99895
# ..                       ...                ...       ...
# 95     plantula1818@live.com     Crystle Larson     74413
# 96  doolittle1818@yandex.com    Jetta Davenport     73152
# 97        mosso1961@live.com    Dallas Johnston     88215
# 98    ovenful1914@yandex.com  Roberto Daugherty     33903
# 99      esson1909@yandex.com       Abel Walters     39186
#
#                       Address   Credit Card Number  Account Balance
# 0     67 John Maher Extension  2524 2317 2139 4751            21511
# 1           1200 Madera Plaza  4756 0997 9568 1329            13850
# 2            943 Gibb Highway    3717 863466 48574            21254
# 3             1073 Fell Trace  5413 1700 6989 2835             5221
# 4      805 Marshall Promenade  5173 4883 9215 4743             8300
# ..                        ...                  ...              ...
# 95  1317 Cesar Chavez On Brae    3474 949615 85541             5091
# 96       618 Williams Terrace  4711 5533 4972 2249            16509
# 97             324 Tenny Line    3794 280688 77410            24196
# 98         1058 Marengo Manor  4972 5355 6633 9108            18828
# 99           89 Rivera Bypass    3727 728484 48704             3400
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Create Columns

# %%
customer_dataframe['Account Balance ($1K)'] = customer_dataframe['Account Balance'] / 1000
customer_dataframe
# Out:
#             Full Name                     Email                    Address  \
# 0     Altha Frederick  unhideable1966@gmail.com    67 John Maher Extension
# 1     Nickolas Harvey   allgood1803@outlook.com          1200 Madera Plaza
# 2     Jesusita Kinney    satsumas1954@yahoo.com           943 Gibb Highway
# 3         Mose Gordon    antifowl1875@gmail.com            1073 Fell Trace
# 4     Cesar Valentine  acetaminol1979@yahoo.com     805 Marshall Promenade
# ..                ...                       ...                        ...
# 95     Crystle Larson     plantula1818@live.com  1317 Cesar Chavez On Brae
# 96    Jetta Davenport  doolittle1818@yandex.com       618 Williams Terrace
# 97    Dallas Johnston        mosso1961@live.com             324 Tenny Line
# 98  Roberto Daugherty    ovenful1914@yandex.com         1058 Marengo Manor
# 99       Abel Walters      esson1909@yandex.com           89 Rivera Bypass
#
#     Zip Code   Credit Card Number  Account Balance  Account Balance ($1K)
# 0      31353  2524 2317 2139 4751            21511                 21.511
# 1       1922  4756 0997 9568 1329            13850                 13.850
# 2      41535    3717 863466 48574            21254                 21.254
# 3      16098  5413 1700 6989 2835             5221                  5.221
# 4      99895  5173 4883 9215 4743             8300                  8.300
# ..       ...                  ...              ...                    ...
# 95     74413    3474 949615 85541             5091                  5.091
# 96     73152  4711 5533 4972 2249            16509                 16.509
# 97     88215    3794 280688 77410            24196                 24.196
# 98     33903  4972 5355 6633 9108            18828                 18.828
# 99     39186    3727 728484 48704             3400                  3.400
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Split Columns

# %%
names = customer_dataframe["Full Name"].str.split(" ", expand=True)

# %%
customer_dataframe['First'] = names[0]
customer_dataframe['Last'] = names[1]

# %%
customer_dataframe
# Out:
#             Full Name                     Email                    Address  \
# 0     Altha Frederick  unhideable1966@gmail.com    67 John Maher Extension
# 1     Nickolas Harvey   allgood1803@outlook.com          1200 Madera Plaza
# 2     Jesusita Kinney    satsumas1954@yahoo.com           943 Gibb Highway
# 3         Mose Gordon    antifowl1875@gmail.com            1073 Fell Trace
# 4     Cesar Valentine  acetaminol1979@yahoo.com     805 Marshall Promenade
# ..                ...                       ...                        ...
# 95     Crystle Larson     plantula1818@live.com  1317 Cesar Chavez On Brae
# 96    Jetta Davenport  doolittle1818@yandex.com       618 Williams Terrace
# 97    Dallas Johnston        mosso1961@live.com             324 Tenny Line
# 98  Roberto Daugherty    ovenful1914@yandex.com         1058 Marengo Manor
# 99       Abel Walters      esson1909@yandex.com           89 Rivera Bypass
#
#     Zip Code   Credit Card Number  Account Balance  Account Balance ($1K)  \
# 0      31353  2524 2317 2139 4751            21511                 21.511
# 1       1922  4756 0997 9568 1329            13850                 13.850
# 2      41535    3717 863466 48574            21254                 21.254
# 3      16098  5413 1700 6989 2835             5221                  5.221
# 4      99895  5173 4883 9215 4743             8300                  8.300
# ..       ...                  ...              ...                    ...
# 95     74413    3474 949615 85541             5091                  5.091
# 96     73152  4711 5533 4972 2249            16509                 16.509
# 97     88215    3794 280688 77410            24196                 24.196
# 98     33903  4972 5355 6633 9108            18828                 18.828
# 99     39186    3727 728484 48704             3400                  3.400
#
#        First       Last
# 0      Altha  Frederick
# 1   Nickolas     Harvey
# 2   Jesusita     Kinney
# 3       Mose     Gordon
# 4      Cesar  Valentine
# ..       ...        ...
# 95   Crystle     Larson
# 96     Jetta  Davenport
# 97    Dallas   Johnston
# 98   Roberto  Daugherty
# 99      Abel    Walters
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Delete Columns

# %%
customer_dataframe = customer_dataframe.drop(columns=['First', 'Last'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-0dc66b50d257> in <module>
# ----> 1 customer_dataframe = customer_dataframe.drop(columns=['First', 'Last'])
#
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['First' 'Last'] not found in axis"

# %%
customer_dataframe
# Out:
#             Full Name                     Email                    Address  \
# 0     Altha Frederick  unhideable1966@gmail.com    67 John Maher Extension
# 1     Nickolas Harvey   allgood1803@outlook.com          1200 Madera Plaza
# 2     Jesusita Kinney    satsumas1954@yahoo.com           943 Gibb Highway
# 3         Mose Gordon    antifowl1875@gmail.com            1073 Fell Trace
# 4     Cesar Valentine  acetaminol1979@yahoo.com     805 Marshall Promenade
# ..                ...                       ...                        ...
# 95     Crystle Larson     plantula1818@live.com  1317 Cesar Chavez On Brae
# 96    Jetta Davenport  doolittle1818@yandex.com       618 Williams Terrace
# 97    Dallas Johnston        mosso1961@live.com             324 Tenny Line
# 98  Roberto Daugherty    ovenful1914@yandex.com         1058 Marengo Manor
# 99       Abel Walters      esson1909@yandex.com           89 Rivera Bypass
#
#     Zip Code   Credit Card Number  Account Balance  Account Balance ($1K)
# 0      31353  2524 2317 2139 4751            21511                 21.511
# 1       1922  4756 0997 9568 1329            13850                 13.850
# 2      41535    3717 863466 48574            21254                 21.254
# 3      16098  5413 1700 6989 2835             5221                  5.221
# 4      99895  5173 4883 9215 4743             8300                  8.300
# ..       ...                  ...              ...                    ...
# 95     74413    3474 949615 85541             5091                  5.091
# 96     73152  4711 5533 4972 2249            16509                 16.509
# 97     88215    3794 280688 77410            24196                 24.196
# 98     33903  4972 5355 6633 9108            18828                 18.828
# 99     39186    3727 728484 48704             3400                  3.400
#
# [100 rows x 7 columns]

# %% [markdown]
# #### Exporting a Dataframe

# %%
customer_dataframe.to_csv("customer_reworked.csv")

# %%
customer_dataframe.loc[98]
# Out:
# Full Name                     Roberto Daugherty
# Email                    ovenful1914@yandex.com
# Address                      1058 Marengo Manor
# Zip Code                                  33903
# Credit Card Number          4972 5355 6633 9108
# Account Balance                           18828
# Account Balance ($1K)                    18.828
# Name: 98, dtype: object
